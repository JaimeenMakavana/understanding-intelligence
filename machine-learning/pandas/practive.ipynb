# %%
import pandas as pd
import numpy as np

# %%
#convert any data structure to series
l1 = pd.Series([10,20,30])
print(l1)
d1 = pd.Series({'a':1 , "b":2})
print(d1)
tu1 = pd.Series((11,12,14))
print(tu1)
print(pd.Series(np.array([1,2,3])))
print(pd.Series(5, index=['a','b','c']))
print(pd.Series(pd.Series([1,2,3])))
print(pd.to_datetime(['2021-01-02','2021-02-03']))
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64
# a    1
# b    2
# dtype: int64
# 0    11
# 1    12
# 2    14
# dtype: int64
# 0    1
# 1    2
# 2    3
# dtype: int64
# a    5
# b    5
# c    5
# dtype: int64
# 0    1
# 1    2
# 2    3
# dtype: int64
# DatetimeIndex(['2021-01-02', '2021-02-03'], dtype='datetime64[ns]', freq=None)

# %%
# pandas series slicing

# %%
s = pd.Series([1,2,3,4,5,6])
print(s[0:3])
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %% [markdown]
# ### Creating dataframe

# %%
print(pd.DataFrame({'a':[1,2,],'b':[3,4]}))
# Out:
#    a  b
# 0  1  3
# 1  2  4

# %%
print(pd.DataFrame([{'a':1,"b":3},{"a":2,"b":4}]))
# Out:
#    a  b
# 0  1  3
# 1  2  4

# %%
print(pd.DataFrame([[1,3],[2,4]], columns=['a','b']))
# Out:
#    a  b
# 0  1  3
# 1  2  4

# %%
print(pd.DataFrame(np.array([[1, 3], [2, 4]]), columns=['a', 'b']))
# Out:
#    a  b
# 0  1  3
# 1  2  4

# %%
pd.DataFrame({
    "a":pd.Series([1,2], index=['x','y']),
    "b":pd.Series([1,2], index=['x','y']),
})
# Out:
#    a  b
# x  1  1
# y  2  2

# %%
s = pd.Series([1,2,3])
df= s.to_frame(name="my_col")

# %%
df
# Out:
#    my_col
# 0       1
# 1       2
# 2       3

# %%
pwd
# Out:
# 'C:\\Users\\jaimeen\\datamites\\03-Pandas'

# %%
import pandas as pd

data = {
    'name': ['Alice', 'Bob', 'Charlie', 'David'],
    'age': [25, 30, 35, 40],
    'city': ['Delhi', 'Mumbai', 'Chennai', 'Kolkata']
}

df = pd.DataFrame(data, index=['a', 'b', 'c', 'd'])
print(df)
# Out:
#       name  age     city
# a    Alice   25    Delhi
# b      Bob   30   Mumbai
# c  Charlie   35  Chennai
# d    David   40  Kolkata

# %%
df.loc['b']
# Out:
# name       Bob
# age         30
# city    Mumbai
# Name: b, dtype: object

# %%
df.loc[df['age'] > 30]
# Out:
#       name  age     city
# c  Charlie   35  Chennai
# d    David   40  Kolkata

# %%
df.loc['b':'d']
# Out:
#       name  age     city
# b      Bob   30   Mumbai
# c  Charlie   35  Chennai
# d    David   40  Kolkata

# %%
df.iloc[1]
# Out:
# name       Bob
# age         30
# city    Mumbai
# Name: b, dtype: object

# %%
df.iloc[2,0]
# Out:
# 'Charlie'

# %%
df.iloc[:,0]
# Out:
# a      Alice
# b        Bob
# c    Charlie
# d      David
# Name: name, dtype: object

# %% [markdown]
# ### handling file`

# %%
df = pd.read_csv("train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df['Pclass']/df[['Pclass']]
# Out:
#      Pclass   0   1   2   3   4   5   6   7   8  ...  881  882  883  884  885  \
# 0       NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN  ...  NaN  NaN  NaN  NaN  NaN
# 1       NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN  ...  NaN  NaN  NaN  NaN  NaN
# 2       NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN  ...  NaN  NaN  NaN  NaN  NaN
# 3       NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN  ...  NaN  NaN  NaN  NaN  NaN
# 4       NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN  ...  NaN  NaN  NaN  NaN  NaN
# ..      ...  ..  ..  ..  ..  ..  ..  ..  ..  ..  ...  ...  ...  ...  ...  ...
# 886     NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN  ...  NaN  NaN  NaN  NaN  NaN
# 887     NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN  ...  NaN  NaN  NaN  NaN  NaN
# 888     NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN  ...  NaN  NaN  NaN  NaN  NaN
# 889     NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN  ...  NaN  NaN  NaN  NaN  NaN
# 890     NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN  ...  NaN  NaN  NaN  NaN  NaN
#
#      886  887  888  889  890
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.loc[2]
# Out:
# PassengerId                         3
# Survived                            1
# Pclass                              3
# Name           Heikkinen, Miss. Laina
# Sex                            female
# Age                              26.0
# SibSp                               0
# Parch                               0
# Ticket               STON/O2. 3101282
# Fare                            7.925
# Cabin                             NaN
# Embarked                            S
# Name: 2, dtype: object

# %%
df.rename({'Survived':'survive'},axis=1,inplace=1)

# %%
df
# Out:
#      PassengerId  survive  Pclass  \
# 0              1        0       3
# 1              2        1       1
# 2              3        1       3
# 3              4        1       1
# 4              5        0       3
# ..           ...      ...     ...
# 886          887        0       2
# 887          888        1       1
# 888          889        0       3
# 889          890        1       1
# 890          891        0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['age_in_month'] = df['Age']*12

# %%
df
# Out:
#      PassengerId  survive  Pclass  \
# 0              1        0       3
# 1              2        1       1
# 2              3        1       3
# 3              4        1       1
# 4              5        0       3
# ..           ...      ...     ...
# 886          887        0       2
# 887          888        1       1
# 888          889        0       3
# 889          890        1       1
# 890          891        0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.rename(columns={'Name':"FullName"}, inplace=True)

# %%
df
# Out:
#      PassengerId  survive  Pclass  \
# 0              1        0       3
# 1              2        1       1
# 2              3        1       3
# 3              4        1       1
# 4              5        0       3
# ..           ...      ...     ...
# 886          887        0       2
# 887          888        1       1
# 888          889        0       3
# 889          890        1       1
# 890          891        0       3
#
#                                               FullName     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.rename(index={0:"first"}, inplace=True)

# %%
df
# Out:
#        PassengerId  survive  Pclass  \
# first            1        0       3
# 1                2        1       1
# 2                3        1       3
# 3                4        1       1
# 4                5        0       3
# ...            ...      ...     ...
# 886            887        0       2
# 887            888        1       1
# 888            889        0       3
# 889            890        1       1
# 890            891        0       3
#
#                                                 FullName     Sex   Age  SibSp  \
# first                            Braund, Mr. Owen Harris    male  22.0      1
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                 Heikkinen, Miss. Laina  female  26.0      0
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                               Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df['Sex'].replace({"male":"M", "female":"F"}, inplace=True)
# Out:
# C:\Users\jaimeen\AppData\Local\Temp\ipykernel_9968\2463492588.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Sex'].replace({"male":"M", "female":"F"}, inplace=True)

# %%
df
# Out:
#        PassengerId  survive  Pclass  \
# first            1        0       3
# 1                2        1       1
# 2                3        1       3
# 3                4        1       1
# 4                5        0       3
# ...            ...      ...     ...
# 886            887        0       2
# 887            888        1       1
# 888            889        0       3
# 889            890        1       1
# 890            891        0       3
#
#                                                 FullName Sex   Age  SibSp  \
# first                            Braund, Mr. Owen Harris   M  22.0      1
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...   F  38.0      1
# 2                                 Heikkinen, Miss. Laina   F  26.0      0
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)   F  35.0      1
# 4                               Allen, Mr. William Henry   M  35.0      0
# ...                                                  ...  ..   ...    ...
# ...

# %%
df['survive'].fillna(df['survive'].mean(),inplace=True)
# Out:
# C:\Users\jaimeen\AppData\Local\Temp\ipykernel_9968\1126700741.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['survive'].fillna(df['survive'].mean(),inplace=True)

# %%
df
# Out:
#        PassengerId  survive  Pclass  \
# first            1        0       3
# 1                2        1       1
# 2                3        1       3
# 3                4        1       1
# 4                5        0       3
# ...            ...      ...     ...
# 886            887        0       2
# 887            888        1       1
# 888            889        0       3
# 889            890        1       1
# 890            891        0       3
#
#                                                 FullName Sex   Age  SibSp  \
# first                            Braund, Mr. Owen Harris   M  22.0      1
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...   F  38.0      1
# 2                                 Heikkinen, Miss. Laina   F  26.0      0
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)   F  35.0      1
# 4                               Allen, Mr. William Henry   M  35.0      0
# ...                                                  ...  ..   ...    ...
# ...

# %%
df.dropna(subset=['Cabin'], inplace=True)

# %%
df
# Out:
#      PassengerId  survive  Pclass  \
# 1              2        1       1
# 3              4        1       1
# 6              7        0       1
# 10            11        1       3
# 11            12        1       1
# ..           ...      ...     ...
# 871          872        1       1
# 872          873        0       1
# 879          880        1       1
# 887          888        1       1
# 889          890        1       1
#
#                                               FullName Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...   F  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)   F  35.0      1
# 6                              McCarthy, Mr. Timothy J   M  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut   F   4.0      1
# 11                            Bonnell, Miss. Elizabeth   F  58.0      0
# ..                                                 ...  ..   ...    ...
# ...

# %%
df['Age'] = df['Age'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 df['Age'] = df['Age'].astype(int)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
# ...

# %%
df['FullName'] = df['FullName'].apply(lambda x: x.upper())

# %%
df
# Out:
#      PassengerId  survive  Pclass  \
# 1              2        1       1
# 3              4        1       1
# 6              7        0       1
# 10            11        1       3
# 11            12        1       1
# ..           ...      ...     ...
# 871          872        1       1
# 872          873        0       1
# 879          880        1       1
# 887          888        1       1
# 889          890        1       1
#
#                                               FullName Sex   Age  SibSp  \
# 1    CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...   F  38.0      1
# 3         FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)   F  35.0      1
# 6                              MCCARTHY, MR. TIMOTHY J   M  54.0      0
# 10                     SANDSTROM, MISS. MARGUERITE RUT   F   4.0      1
# 11                            BONNELL, MISS. ELIZABETH   F  58.0      0
# ..                                                 ...  ..   ...    ...
# ...

# %%
df.sort_values(by="Age", ascending=False, inplace=True)

# %%
df
# Out:
#      PassengerId  survive  Pclass  \
# 630          631        1       1
# 96            97        0       1
# 745          746        0       1
# 54            55        0       1
# 456          457        0       1
# ..           ...      ...     ...
# 740          741        1       1
# 776          777        0       3
# 815          816        0       1
# 839          840        1       1
# 849          850        1       1
#
#                                          FullName Sex   Age  SibSp  Parch  \
# 630          BARKWORTH, MR. ALGERNON HENRY WILSON   M  80.0      0      0
# 96                      GOLDSCHMIDT, MR. GEORGE B   M  71.0      0      0
# 745                  CROSBY, CAPT. EDWARD GIFFORD   M  70.0      1      1
# 54                 OSTBY, MR. ENGELHART CORNELIUS   M  65.0      0      1
# 456                     MILLET, MR. FRANCIS DAVIS   M  65.0      0      0
# ..                                            ...  ..   ...    ...    ...
# ...

# %%
df.set_index('survice', inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9968\990646406.py in ?()
# ----> 1 df.set_index('survice', inplace=True)
#       2 df
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#    6125             frame = self
#
# KeyError: "None of ['survice'] are in the columns"
